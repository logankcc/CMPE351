# %%
import gzip
import json
import pandas as pd

# %%
def parse_gzipped_json_generator(zip_file_path):
    with gzip.open(zip_file_path, 'rt', encoding='utf-8') as file:
        for line in file:
            yield json.loads(line)

def gzipped_json_to_dataframe(zip_file_path):
    generator = parse_gzipped_json_generator(zip_file_path)
    data_frame = pd.DataFrame(generator)
    return data_frame

# %%
review_zip_file_path = '../data/review-New_York_10.json.gz'
review_data_frame = gzipped_json_to_dataframe(review_zip_file_path)
review_data_frame.head()
# Out:
#                  user_id             name           time  rating  \
# 0  113722104692308235141   Alvin Martinez  1603494795361       5
# 1  107293441492109320298  Johnnie Jackson  1620157037403       1
# 2  100378585801819400296     Manie Blazer  1597431662039       5
# 3  114998161153019826512   Fashion Fiinds  1543773862044       5
# 4  117178185728422297915   Andres Rieloff  1597279097718       1
#
#                                                 text  \
# 0  I'm late to posting this but this store especi...
# 1  Very dissatisfied I did not get my phone the p...
# 2  Excellent very well done with professional car...
# 3  Basing my review strictly on the service I rec...
# 4  Bad! Disorganized. I'm being totally honest. I...
#
#                                                 pics  \
# 0  [{'url': ['https://lh5.googleusercontent.com/p...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                 resp  \
# 0                                               None
# 1  {'time': 1620268360920, 'text': 'We pride ours...
# 2                                               None
# 3  {'time': 1543855317372, 'text': 'Thanks for th...
# 4                                               None
#
#                                gmap_id
# 0  0x89c25fc9494dce47:0x6d63c807b59a55
# 1  0x89c25fc9494dce47:0x6d63c807b59a55
# 2  0x89c25fc9494dce47:0x6d63c807b59a55
# 3  0x89c25fc9494dce47:0x6d63c807b59a55
# 4  0x89c25fc9494dce47:0x6d63c807b59a55

# %%
meta_zip_file_path = '../data/meta-New_York.json.gz'
meta_data_frame = gzipped_json_to_dataframe(meta_zip_file_path)
meta_data_frame = meta_data_frame[meta_data_frame['category'].astype(str).str.contains('restaurant', case=False, na=False)]
meta_data_frame = meta_data_frame.drop_duplicates(subset='gmap_id')
meta_data_frame.head()
# Out:
#                               name  \
# 42                         Dunkin'
# 54          Raffaello Kosher Pizza
# 68                   Casa Malinche
# 81  Kennedy's Chicken & Sandwiches
# 98                   Cafe Kristall
#
#                                               address  \
# 42          Dunkin', 4008 Bell Blvd, Queens, NY 11361
# 54  Raffaello Kosher Pizza, 37 W 46th St, New York...
# 68  Casa Malinche, 3078 Coney Island Ave, Brooklyn...
# 81  Kennedy's Chicken & Sandwiches, 495 E 138th St...
# 98    Cafe Kristall, 70 Mercer St, New York, NY 10012
#
#                                   gmap_id  \
# 42  0x89c261f60bdf13db:0x38da730e4687a97b
# 54  0x89c258ffaeaba947:0x8355860772a595a9
# 68  0x89c244427d3e2c19:0xc1dbf7d8e71d7201
# 81  0x89c2f5c3caef3fb5:0xb7f855503b4bc974
# 98  0x89c2598eb0b90839:0x2b3c5161280e7169
#
#                                           description   latitude  longitude  \
# 42  Long-running chain serving signature breakfast...  40.763985 -73.771430
# 54  This casual joint serves up traditional Italia...  40.756872 -73.980427
# 68                                               None  40.581086 -73.960139
# 81                                               None  40.808010 -73.919617
# 98  Austrian cuisine & drinks in a small, crystal-...  40.722466 -74.000283
#
#                                              category  avg_rating  \
# 42  [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.5
# 54                                       [Restaurant]         3.4
# 68                               [Mexican restaurant]         4.4
# 81                             [Fast food restaurant]         3.7
# 98                                 [Cafe, Restaurant]         5.0
#
#     num_of_reviews price                                              hours  \
# 42               8     $  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 54               8  None                                               None
# 68               7  None  [[Thursday, 11AM–9:30PM], [Friday, 11AM–9:30PM...
# 81               8  None  [[Thursday, 8AM–3AM], [Friday, 8AM–3AM], [Satu...
# 98               1    $$                                               None
#
#                                                  MISC               state  \
# 42  {'Service options': ['Delivery', 'Takeout', 'D...   Open ⋅ Closes 7PM
# 54  {'Service options': ['Delivery'], 'Offerings':...                None
# 68  {'Service options': ['Delivery'], 'Amenities':...  Permanently closed
# 81  {'Service options': ['Takeout', 'Dine-in', 'De...  Closed ⋅ Opens 8AM
# 98  {'Service options': ['Delivery'], 'Offerings':...                None
#
#                                      relative_results  \
# 42  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 54  [0x89c2f41bdce4dc0f:0xf4e3f717a4950ea3, 0x89c2...
# 68  [0x89c24434f14337c9:0xbfa6dd0a67a97aa4, 0x89c2...
# 81  [0x89c2f5cfbcdeb7c1:0x1c3c27e3a6bcdab6, 0x89c2...
# 98  [0x89c25a18157c4c95:0x544d671533dccc36, 0x89c2...
#
#                                                   url
# 42  https://www.google.com/maps/place//data=!4m2!3...
# 54  https://www.google.com/maps/place//data=!4m2!3...
# 68  https://www.google.com/maps/place//data=!4m2!3...
# 81  https://www.google.com/maps/place//data=!4m2!3...
# 98  https://www.google.com/maps/place//data=!4m2!3...

# %%
merged_data_frame = pd.merge(review_data_frame, meta_data_frame, on='gmap_id', how='inner')
merged_data_frame.head()
# Out:
#                  user_id                  name_x           time  rating  \
# 0  101863461389011299215  Maria Patricia Londoño  1629077998394       4
# 1  101954633332535852944                 Kristal  1593616678555       5
# 2  108987684095941070060        Efrain Hernandez  1594150943631       3
# 3  110146321170975563919            Kiyoshi Sudo  1564776340103       5
# 4  112625885159369009229      Charlotte Sheppard  1602429271233       1
#
#                                                 text  \
# 0  The donuts is always a good place to buy somet...
# 1  I went into this Dunkin' yesterday and got som...
# 2  Bought a Machiato and as soon as I touched the...
# 3  Friendly staffs, nice donuts and muffins and c...
# 4  They got my order wrong  food wasn't done unco...
#
#                                                 pics  resp  \
# 0                                               None  None
# 1  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
#
#                                  gmap_id   name_y  \
# 0  0x89c261f60bdf13db:0x38da730e4687a97b  Dunkin'
# 1  0x89c261f60bdf13db:0x38da730e4687a97b  Dunkin'
# 2  0x89c261f60bdf13db:0x38da730e4687a97b  Dunkin'
# 3  0x89c261f60bdf13db:0x38da730e4687a97b  Dunkin'
# 4  0x89c261f60bdf13db:0x38da730e4687a97b  Dunkin'
#
#                                      address  ... longitude  \
# 0  Dunkin', 4008 Bell Blvd, Queens, NY 11361  ... -73.77143
# 1  Dunkin', 4008 Bell Blvd, Queens, NY 11361  ... -73.77143
# 2  Dunkin', 4008 Bell Blvd, Queens, NY 11361  ... -73.77143
# 3  Dunkin', 4008 Bell Blvd, Queens, NY 11361  ... -73.77143
# 4  Dunkin', 4008 Bell Blvd, Queens, NY 11361  ... -73.77143
#
#                                             category  avg_rating  \
# 0  [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.5
# 1  [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.5
# 2  [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.5
# 3  [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.5
# 4  [Coffee shop, Bagel shop, Bakery, Breakfast re...         3.5
#
#   num_of_reviews  price                                              hours  \
# 0              8      $  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 1              8      $  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 2              8      $  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 3              8      $  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
# 4              8      $  [[Thursday, 6AM–7PM], [Friday, 6AM–7PM], [Satu...
#
#                                                 MISC              state  \
# 0  {'Service options': ['Delivery', 'Takeout', 'D...  Open ⋅ Closes 7PM
# 1  {'Service options': ['Delivery', 'Takeout', 'D...  Open ⋅ Closes 7PM
# 2  {'Service options': ['Delivery', 'Takeout', 'D...  Open ⋅ Closes 7PM
# 3  {'Service options': ['Delivery', 'Takeout', 'D...  Open ⋅ Closes 7PM
# 4  {'Service options': ['Delivery', 'Takeout', 'D...  Open ⋅ Closes 7PM
#
#                                     relative_results  \
# 0  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 1  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 2  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 3  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
# 4  [0x89c3ab9229879ec3:0x3f4b2b46d7d2c503, 0x89c2...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...
#
# [5 rows x 22 columns]

# %%
sample_data_frame = merged_data_frame.sample(n=1000000, random_state=69)
sample_data_frame.to_json('../data/sample_new_york_data.json', orient='records')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
